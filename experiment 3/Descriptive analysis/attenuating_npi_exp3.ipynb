# %% [markdown]
# ## Лист 1

# %%
df_Q1_long = df_Q1.melt(
    id_vars=['Item', 'Condition', 'Mood', 'Degmod'],
    value_vars=['gemini', 'qwen', 'llama', 'mistral', 'moonlight',
                'gemma', 'deephermes', 'ds_distill_llama'],
    var_name='Model',
    value_name='Rating'
)

# %%
df_Q1_long.groupby('Condition')['Rating'].mean()
# Out:
# Condition
# 1    4.703125
# 2    1.723958
# 3    4.760417
# 4    2.078125
# Name: Rating, dtype: float64

# %%
df_Q1_long.groupby('Condition')['Rating'].std()
# Out:
# Condition
# 1    1.493578
# 2    1.307189
# 3    1.553545
# 4    1.391500
# Name: Rating, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

summary = df_Q1_long.groupby('Condition')['Rating'].agg(['mean', 'std']).reset_index()

condition_labels = {
    1: 'гип. инд. без very',
    2: 'контрфакт. без very',
    3: 'гип. инд. с very',
    4: 'контрфакт. с very',
}

summary['Condition_label'] = summary['Condition'].map(condition_labels)

fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

# График средних
sns.barplot(
    data=summary,
    x='Condition_label',
    y='mean',
    palette='Blues_d',
    edgecolor='black',
    ax=axs[0]
)
axs[0].set_title('Средние оценки')
axs[0].tick_params(axis='x', rotation=30)
axs[0].set_ylim(1, 7)

# График стандартных отклонений
sns.barplot(
    data=summary,
    x='Condition_label',
    y='std',
    palette='Purples_d',
    edgecolor='black',
    ax=axs[1]
)
axs[1].set_title('Стандартные отклонения оценок')
axs[1].tick_params(axis='x', rotation=30)
axs[1].set_ylim(0, summary['std'].max() + 0.5)
fig.supxlabel('Тип конструкции', fontsize=12)
fig.supylabel('Значения оценок', fontsize=12)

axs[0].set_xlabel('')
axs[0].set_ylabel('Значения оценок')
axs[1].set_xlabel('')
axs[1].set_ylabel('Значения станд. откл.')

fig.text(0.5, -0.05, 'Рис. 6. Сравнение типов предложений по средним их оценок и стандартным отклонениям (эксп. 3 вопрос 1)',
         ha='center', fontsize=10)

plt.show()
# Out:
# <ipython-input-7-6d301658fece>:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-7-6d301658fece>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_Q1_long.groupby(['Model'])['Rating'].std().mean()
# Out:
# np.float64(1.7975560433374076)

# %%
df_Q1_long.groupby(['Item'])['Rating'].std().mean()
# Out:
# np.float64(1.9407271115516682)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


condition_labels = {
    1: 'гип. инд. с NPI',
    2: 'контрфакт. с NPI',
    3: 'гип. инд. без NPI',
    4: 'контрфакт. без NPI',
    5: 'инд. + all и NPI',
    6: 'инд. + all без NPI'
}

df_copy = df_Q1_long.copy()
df_copy['Condition_label'] = df_copy['Condition'].map(condition_labels)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=df_copy,
    x='Condition_label',
    y='Rating',
    hue='Model',
    ci=None
)

plt.xlabel('Условие')
plt.ylabel('Оценка')
plt.xticks(rotation=30)
plt.legend(title='Модель')
plt.gcf().text(0.5, -0.02, 'Рис. 2. Сравнение средних оценок по условиям и моделям (эксп. 1)',
         ha='center', fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-6-59b8d75ffb79>:18: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
df_Q1_long.to_excel('exp3_Q1.xlsx', index=False)

# %% [markdown]
# ## Лист 2

# %%
df_Q2_long = df_Q2.melt(
    id_vars=['Item', 'Condition', 'Mood', 'Degmod'],
    value_vars=['gemini', 'qwen', 'llama', 'mistral', 'moonlight',
                'gemma', 'deephermes', 'ds_distill_llama'],
    var_name='Model',
    value_name='Rating'
)

# %%
df_Q2_long.groupby(['Condition'])['Rating'].mean()
# Out:
# Condition
# 1    6.677083
# 2    6.510417
# 3    6.625000
# 4    6.427083
# Name: Rating, dtype: float64

# %%
df_Q2_long.groupby(['Condition'])['Rating'].std()
# Out:
# Condition
# 1    0.779244
# 2    1.310408
# 3    0.895012
# 4    1.351709
# Name: Rating, dtype: float64

# %%
df_Q2_long.groupby(['Model'])['Rating'].std().mean()
# Out:
# np.float64(0.8676978006582052)

# %%
df_Q2_long.groupby(['Item'])['Rating'].std().mean()
# Out:
# np.float64(0.9084416771739438)

# %%
summary2 = df_Q2_long.groupby('Condition')['Rating'].agg(['mean', 'std']).reset_index()

condition_labels = {
    1: 'гип. инд. без very',
    2: 'контрфакт. без very',
    3: 'гип. инд. с very',
    4: 'контрфакт. с very',
}

summary2['Condition_label'] = summary2['Condition'].map(condition_labels)

fig, axs = plt.subplots(1, 2, figsize=(10, 5), constrained_layout=True)

sns.barplot(
    data=summary2,
    x='Condition_label',
    y='mean',
    palette='Blues_d',
    edgecolor='black',
    ax=axs[0]
)
axs[0].set_title('Средние оценки')
axs[0].tick_params(axis='x', rotation=30)
axs[0].set_ylim(1, 7)

sns.barplot(
    data=summary2,
    x='Condition_label',
    y='std',
    palette='Purples_d',
    edgecolor='black',
    ax=axs[1]
)
axs[1].set_title('Стандартные отклонения оценок')
axs[1].tick_params(axis='x', rotation=30)
axs[1].set_ylim(0, summary2['std'].max() + 0.5)
fig.supxlabel('Тип конструкции', fontsize=12)
fig.supylabel('Значения оценок', fontsize=12)

axs[0].set_xlabel('')
axs[0].set_ylabel('Значения оценок')
axs[1].set_xlabel('')
axs[1].set_ylabel('Значения станд. откл.')

fig.text(0.5, -0.05, 'Рис. 7. Сравнение типов предложений по средним их оценок и стандартным отклонениям (эксп. 3 вопрос 2)',
         ha='center', fontsize=10)

plt.show()
# Out:
# <ipython-input-10-83e9fa2d7ad9>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <ipython-input-10-83e9fa2d7ad9>:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
df_copy1 = df_Q1_long.copy()
df_copy1['Condition_label'] = df_copy1['Condition'].map(condition_labels)

df_copy2 = df_Q2_long.copy()
df_copy2['Condition_label'] = df_copy2['Condition'].map(condition_labels)

fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=True)

sns.barplot(
    data=df_copy1,
    x='Condition_label',
    y='Rating',
    hue='Model',
    errorbar=None,
    legend=False,
    ax=axs[0]
)
axs[0].set_title('Вопрос 1')
axs[0].set_xlabel('')
axs[0].set_ylabel('Оценка')
axs[0].tick_params(axis='x', rotation=30)

sns.barplot(
    data=df_copy2,
    x='Condition_label',
    y='Rating',
    hue='Model',
    errorbar=None,
    ax=axs[1]
)
axs[1].set_title('Вопрос 2')
axs[1].set_xlabel('')
axs[1].set_ylabel('Оценка')
axs[1].legend(title='Модель', bbox_to_anchor=(1, 1), loc='upper left')
axs[1].tick_params(axis='x', rotation=30)

fig.supxlabel('Тип конструкции', fontsize=12)
fig.text(0.5, -0.05, 'Рис. 8. Сравнение средних оценок по условным конструкциям и моделям (эксп. 3)', ha='center', fontsize=12)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=True)

sns.barplot(
    data=df_copy1,
    x='Model',
    y='Rating',
    hue='Condition_label',
    errorbar=None,
    legend=False,
    ax=axs[0]
)
axs[0].set_title('Вопрос 1')
axs[0].set_xlabel('')
axs[0].set_ylabel('Оценка')
axs[0].tick_params(axis='x', rotation=30)

sns.barplot(
    data=df_copy2,
    x='Model',
    y='Rating',
    hue='Condition_label',
    errorbar=None,
    ax=axs[1]
)
axs[1].set_title('Вопрос 2')
axs[1].set_xlabel('')
axs[1].set_ylabel('Оценка')
axs[1].legend(title='Тип конструкции', bbox_to_anchor=(1, 1), loc='upper left')
axs[1].tick_params(axis='x', rotation=30)

fig.supxlabel('Модель', fontsize=12)
plt.tight_layout()
plt.show()

# %%
df_Q2_long.to_excel('exp3_Q2.xlsx', index=False)
